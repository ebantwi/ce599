# %% [markdown]
# # Data visualization with seaborn
# ### Statistical data visualization
#
# Last week we used pandas and matplotlib to make some basic graphs.  This time we will start to explore the data statistically, and use seaborn for statistical data visualization.  The point is to explore the relationships in the data.  This exercise is based on the seaborn tutorial.  For reference:
#
# http://seaborn.pydata.org/index.html
#
# We won't cover them here, but if you get into this stuff you might check out:
#
# bokeh: does interactive data viz, much like we did interactive mapping earlier.
#
# http://bokeh.pydata.org/en/latest/
#
# d3: this is a javascript library that has been used to create some of the most beautiful visualizations I have ever seen.
#
# https://github.com/d3/d3/wiki/Gallery

# %% [markdown]
# ## Install
#
#     conda install seaborn

# %%
# magic command to display matplotlib plots inline within the ipython notebook webpage
# %matplotlib inline

# import necessary modules
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %% [markdown]
# ## Load the data sets
#
# In this exercise, we are interested in understanding more about the congested roadway speed.  We may want to see what the speed distribution looks like, and how it relates to other variables.  We'll examine this today.

# %%
# This file contains the street network of San Francisco.  
# Each link has a modeled traffic volume and travel time for the 5-6 pm period. 
df = pd.read_csv('data/project_flatdata_scrubbed.csv')

# see what we have
df.head()
# Out:
#    HashProjectID  AverageCount  AverageForecast    Error  AbsError  \
# 0              1       67797.5         69861.25 -2063.75   2063.75
# 1              2       99720.0         99724.00    -4.00      4.00
# 2              3       28800.0         31001.00 -2201.00   2201.00
# 3              4        4610.0          4910.00  -300.00    300.00
# 4              5       53705.0         60317.50 -6612.50   6612.50
#
#    PercentError      AbsPE  UnemploymentRate_ForecastYear  \
# 0     -2.954070   2.954070                            5.4
# 1     -0.004011   0.004011                            8.9
# 2     -7.099771   7.099771                            6.5
# 3     -6.109980   6.109980                           10.2
# 4    -10.962822  10.962822                            6.5
#
#    UnemploymentRate_YearProduced  UnemploymentRate_OpeningYear  Diff_Year  \
# 0                            6.3                           5.4          1
# 1                            8.9                          10.2          5
# 2                            5.9                           6.5          3
# 3                           10.3                          10.2          1
# 4                            5.9                           6.5          5
#
#    UnifiedImprovementType  Forecast_Method  Area_Type  ForecastYear  \
# 0                       2                6          3          2005
# 1                       1                6          3          2017
# 2                       3                6          3          2009
# 3                       1                6          3          2010
# 4                       1                6          3          2010
#
#    YearForecastProduced  Year_ofObservation  ImprovementType  Agency  \
# 0                  2004              2006.0               11       6
# 1                  2012              2010.0                1       6
# 2                  2006              2008.0               12       6
# 3                  2009              2010.0                1       6
# 4                  2005              2008.0                3       6
#
#    FunctionalClass
# 0                1
# 1                1
# 2                1
# 3                5
# 4                1

# %% [markdown]
# ## Plotting univariate distributions
#
# The most convenient way to take a quick look at a univariate distribution in seaborn is the distplot() function. By default, this will draw a histogram and fit a kernel density estimate (KDE).

# %%
sns.distplot(df['PercentError'])

# %% [markdown]
# If we want to control the limits of the x axes, we need to use the matplotlib commands like we did last week.

# %%
ax = sns.distplot(df['PercentError'])
ax.figure.set_size_inches(8,6)
ax.set_xlim(-75,75)
# Out:
# (-75, 75)

# %% [markdown]
# distplot() actually gives a combination of a histogram and a kernel density plot.  You can get just one or the other, and control the number of bins.
#
# Alternatively, you can also add a rug plot which gives a vertical tick for each observation.

# %%
ax = sns.distplot(df['PercentError'], kde=False, bins=100)
ax.figure.set_size_inches(8,6)
ax.set_xlim(-75,75)
# Out:
# (-75, 75)

# %% [markdown]
# The kernel density estimate may be less familiar, but it can be a useful tool for plotting the shape of a distribution. Like the histogram, the KDE plots encodes the density of observations on one axis with height along the other axis.
#
# Drawing a KDE is more computationally involved than drawing a histogram. What happens is that each observation is first replaced with a normal (Gaussian) curve centered at that value.
#
# Next, these curves are summed to compute the value of the density at each point in the support grid. The resulting curve is then normalized so that the area under it is equal to 1.

# %% [markdown]
# The bandwidth (bw) parameter of the KDE controls how tightly the estimation is fit to the data, much like the bin size in a histogram. It corresponds to the width of the kernels we plotted above. The default behavior tries to guess a good value using a common reference rule, but it may be helpful to try larger or smaller values.

# %%
ax = sns.kdeplot(df['PercentError'], label='default')
ax = sns.kdeplot(df['PercentError'], bw=.1, label="bw: 0.1")
ax = sns.kdeplot(df['PercentError'], bw=2, label="bw: 2")

ax.set_xlim(-75,75)
plt.legend();

# %% [markdown]
# You can also use distplot() to fit a parametric distribution to a dataset and visually evaluate how closely it corresponds to the observed data:

# %%
import numpy as np

# here we try to fit a normal distribution
ax = sns.distplot(df['PercentError'], kde=False, fit=stats.norm)
ax.figure.set_size_inches(8,6)
ax.set_xlim(-75,75)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3b36734bf90b> in <module>
#       2
#       3 # here we try to fit a normal distribution
# ----> 4 ax = sns.distplot(df['PercentError'], kde=False, fit=stats.norm)
#       5 ax.figure.set_size_inches(8,6)
#       6 ax.set_xlim(-75,75)
#
# NameError: name 'stats' is not defined

# %% [markdown]
# In the above case, the normal distribution doesn't fit very well.  This can be an issue because many statistical tests are based on an assumption that your data follows a particular distribution.  If it doesn't, the test may be invalid.  This is why it is important to actually visualize it.

# %% [markdown]
# ## Plotting bivariate distributions
#
# It can also be useful to visualize a bivariate distribution of two variables. The easiest way to do this in seaborn is to just the jointplot() function, which creates a multi-panel figure that shows both the bivariate (or joint) relationship between two variables along with the univariate (or marginal) distribution of each on separate axes.

# %% [markdown]
# #### Scatterplots
#
# The most familiar way to visualize a bivariate distribution is a scatterplot, where each observation is shown with point at the x and y values. This is analgous to a rug plot on two dimensions. You can draw a scatterplot with the matplotlib plt.scatter function, and it is also the default kind of plot shown by the jointplot() function:

# %%
# plot the speed vs traffic volume
sns.jointplot(x="AverageForecast", y="AverageCount", data=df, size=8)
# Out:
# /Users/eugene/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Hexbin plots
#
# There are a lot of points in the bottom left, so its hard to see what is going on.  We can look at this a bit better using something called a hexbin plot.
#
# The bivariate analogue of a histogram is known as a “hexbin” plot, because it shows the counts of observations that fall within hexagonal bins. This plot works best with relatively large datasets. It’s availible through the matplotlib plt.hexbin function and as a style in jointplot(). It looks best with a white background:

# %%
# plot the speed vs traffic volume
sns.jointplot(x="AverageForecast", 
              y="AverageCount", 
              data=df, 
              kind='hex', 
              size=8)

# %% [markdown]
# #### Kernel density estimation
#
# It is also posible to use the kernel density estimation procedure described above to visualize a bivariate distribution. In seaborn, this kind of plot is shown with a contour plot and is available as a style in jointplot():

# %%
# plot the speed vs traffic volume
sns.jointplot(x="AverageForecast", 
              y="AverageCount", 
              data=df, 
              kind='kde', 
              size=8, 
              bw=2)

# %% [markdown]
# ## Visualizing pairwise relationships in a dataset
#
# To plot multiple pairwise bivariate distributions in a dataset, you can use the pairplot() function. This creates a matrix of axes and shows the relationship for each pair of columns in a DataFrame. by default, it also draws the univariate distribution of each variable on the diagonal Axes:

# %%
# only for selected columns
cols = ['AbsPE', 'PercentError', 'AverageForecast', 'UnemploymentRate_OpeningYear', 'Diff_Year']

# and teh plots
sns.pairplot(df[cols])

# %% [markdown]
# ## Drawing linear regression models
#
# We can easily draw a scatterplot and fit a linear regression model.

# %%
sns.regplot(x="AverageCount", y="AverageForecast", data=df);

# %% [markdown]
# Or we can make this different for freeways vs non-freeways.

# %%
# freeways are facility type 1
df['Freeway'] = df['FunctionalClass'].apply(lambda x : 'Freeway' if x==1 else 'Other')

sns.lmplot(x="AverageCount", y="AverageForecast", hue='Freeway', data=df);

# %% [markdown]
# ## Exploring categories
# We previously learned how to use scatterplots and regression model fits to visualize the relationship between two variables and how it changes across levels of additional categorical variables. However, what if one of the main variables you are interested in is categorical? In this case, the scatterplot and regression model approach won’t work. There are several options, however, for visualizing such a relationship, which we will discuss in this tutorial.

# %% [markdown]
# #### Categorical scatterplots
#
# A simple way to show the the values of some quantitative variable across the levels of a categorical variable uses stripplot(), which generalizes a scatterplot to the case where one of the variables is categorical:

# %%
sns.stripplot(x="FunctionalClass", y="PercentError", data=df)

# %% [markdown]
# #### Boxplots
#
# At a certain point, the categorical scatterplot approach becomes limited in the information it can provide about the distribution of values within each category. There are several ways to summarize this information in ways that facilitate easy comparisons across the category levels. These generalize some of the approaches we discussed in the chapter to the case where we want to quickly compare across several distributions.
#
# The first is the familiar boxplot(). This kind of plot shows the three quartile values of the distribution along with extreme values. The “whiskers” extend to points that lie within 1.5 IQRs of the lower and upper quartile, and then observations that fall outside this range are displayed independently. Importantly, this means that each value in the boxplot corresponds to an actual observation in the data:

# %%
sns.boxplot(x="FunctionalClass", y="PercentError", data=df)

# %% [markdown]
# #### Violinplots
#
# A different approach is a violinplot(), which combines a boxplot with the kernel density estimation procedure described in the distributions tutorial:

# %%
sns.violinplot(x="FunctionalClass", y="PercentError", data=df)

# %% [markdown]
# # Homework
#
# Explore this data set and explain which factors most affect the percent error and absolute percent error.  Use visualizations to support your case.  Your should first conduct an exploratory analysis, and then once you have figured out your story, clearly label a section with just the relevant explanation and supporting figures.  Make it easy for me to review just the 'bottom line'!

# %%
df.corr()
# Out:
#                                HashProjectID  AverageCount  AverageForecast  \
# HashProjectID                       1.000000      0.087523         0.061932
# AverageCount                        0.087523      1.000000         0.978148
# AverageForecast                     0.061932      0.978148         1.000000
# Error                               0.087327     -0.259043        -0.454197
# AbsError                            0.043488      0.447562         0.546863
# PercentError                        0.243037      0.051350        -0.080120
# AbsPE                               0.099560     -0.161270        -0.141177
# UnemploymentRate_ForecastYear      -0.253575     -0.023088         0.003315
# UnemploymentRate_YearProduced       0.250451      0.106239         0.101719
# UnemploymentRate_OpeningYear       -0.284468      0.010911         0.038716
# Diff_Year                           0.461036      0.019208        -0.020834
# UnifiedImprovementType              0.245660     -0.029463        -0.050855
# Forecast_Method                     0.061944      0.071242         0.094120
# Area_Type                           0.594522      0.076622         0.070902
# ForecastYear                       -0.345436      0.123478         0.149711
# YearForecastProduced               -0.397139      0.079344         0.116053
# Year_ofObservation                 -0.283651      0.129281         0.160065
# ImprovementType                     0.014163      0.017443         0.004083
# Agency                             -0.404996      0.049027         0.066050
# FunctionalClass                     0.643019     -0.197636        -0.222904
#
#                                   Error  AbsError  PercentError     AbsPE  \
# HashProjectID                  0.087327  0.043488      0.243037  0.099560
# AverageCount                  -0.259043  0.447562      0.051350 -0.161270
# AverageForecast               -0.454197  0.546863     -0.080120 -0.141177
# Error                          1.000000 -0.622681      0.592237 -0.035195
# AbsError                      -0.622681  1.000000     -0.136913  0.391959
# PercentError                   0.592237 -0.136913      1.000000  0.252388
# AbsPE                         -0.035195  0.391959      0.252388  1.000000
# UnemploymentRate_ForecastYear -0.114332 -0.041783     -0.109685 -0.114637
# UnemploymentRate_YearProduced -0.017312 -0.023776      0.046650 -0.108955
# UnemploymentRate_OpeningYear  -0.133105 -0.004877     -0.126726 -0.119550
# Diff_Year                      0.179091  0.107088      0.230272  0.217720
# UnifiedImprovementType         0.110001  0.014489      0.169415  0.160662
# Forecast_Method               -0.131971 -0.049214     -0.081484 -0.127769
# Area_Type                     -0.001057  0.030148      0.118907  0.074924
# ForecastYear                  -0.166390  0.012406     -0.284819 -0.247267
# YearForecastProduced          -0.199141 -0.056072     -0.296413 -0.290541
# Year_ofObservation            -0.189619  0.037824     -0.251330 -0.184862
# ImprovementType                0.055775  0.067371      0.052886  0.121001
# Agency                        -0.096758 -0.028999     -0.147591 -0.187950
# FunctionalClass                0.188645 -0.067347      0.171529  0.225149
#
#                                UnemploymentRate_ForecastYear  \
# HashProjectID                                      -0.253575
# AverageCount                                       -0.023088
# AverageForecast                                     0.003315
# Error                                              -0.114332
# AbsError                                           -0.041783
# PercentError                                       -0.109685
# AbsPE                                              -0.114637
# UnemploymentRate_ForecastYear                       1.000000
# UnemploymentRate_YearProduced                       0.024966
# UnemploymentRate_OpeningYear                        0.803520
# Diff_Year                                          -0.332196
# UnifiedImprovementType                             -0.327024
# Forecast_Method                                     0.322415
# Area_Type                                          -0.038831
# ForecastYear                                        0.159560
# YearForecastProduced                                0.252636
# Year_ofObservation                                  0.105990
# ImprovementType                                    -0.299233
# Agency                                              0.471783
# FunctionalClass                                    -0.434333
#
#                                UnemploymentRate_YearProduced  \
# HashProjectID                                       0.250451
# AverageCount                                        0.106239
# AverageForecast                                     0.101719
# Error                                              -0.017312
# AbsError                                           -0.023776
# PercentError                                        0.046650
# AbsPE                                              -0.108955
# UnemploymentRate_ForecastYear                       0.024966
# UnemploymentRate_YearProduced                       1.000000
# UnemploymentRate_OpeningYear                        0.065779
# Diff_Year                                          -0.187641
# UnifiedImprovementType                             -0.127703
# Forecast_Method                                     0.316841
# Area_Type                                           0.296260
# ForecastYear                                        0.297625
# YearForecastProduced                                0.305899
# Year_ofObservation                                  0.226051
# ImprovementType                                    -0.134245
# Agency                                              0.089336
# FunctionalClass                                     0.045099
#
#                                UnemploymentRate_OpeningYear  Diff_Year  \
# HashProjectID                                     -0.284468   0.461036
# AverageCount                                       0.010911   0.019208
# AverageForecast                                    0.038716  -0.020834
# Error                                             -0.133105   0.179091
# AbsError                                          -0.004877   0.107088
# PercentError                                      -0.126726   0.230272
# AbsPE                                             -0.119550   0.217720
# UnemploymentRate_ForecastYear                      0.803520  -0.332196
# UnemploymentRate_YearProduced                      0.065779  -0.187641
# UnemploymentRate_OpeningYear                       1.000000  -0.349508
# Diff_Year                                         -0.349508   1.000000
# UnifiedImprovementType                            -0.342943   0.394032
# Forecast_Method                                    0.266598  -0.427424
# Area_Type                                         -0.080655   0.221174
# ForecastYear                                       0.212528  -0.453070
# YearForecastProduced                               0.282842  -0.751871
# Year_ofObservation                                 0.130307  -0.490977
# ImprovementType                                   -0.268347   0.348666
# Agency                                             0.497271  -0.425811
# FunctionalClass                                   -0.465833   0.484444
#
#                                UnifiedImprovementType  Forecast_Method  \
# HashProjectID                                0.245660         0.061944
# AverageCount                                -0.029463         0.071242
# AverageForecast                             -0.050855         0.094120
# Error                                        0.110001        -0.131971
# AbsError                                     0.014489        -0.049214
# PercentError                                 0.169415        -0.081484
# AbsPE                                        0.160662        -0.127769
# UnemploymentRate_ForecastYear               -0.327024         0.322415
# UnemploymentRate_YearProduced               -0.127703         0.316841
# UnemploymentRate_OpeningYear                -0.342943         0.266598
# Diff_Year                                    0.394032        -0.427424
# UnifiedImprovementType                       1.000000        -0.358108
# Forecast_Method                             -0.358108         1.000000
# Area_Type                                    0.160816         0.502525
# ForecastYear                                -0.469007         0.181944
# YearForecastProduced                        -0.477654         0.378636
# Year_ofObservation                          -0.386851         0.227446
# ImprovementType                              0.877482        -0.486378
# Agency                                      -0.690365         0.514207
# FunctionalClass                              0.452535        -0.218833
#
#                                Area_Type  ForecastYear  YearForecastProduced  \
# HashProjectID                   0.594522     -0.345436             -0.397139
# AverageCount                    0.076622      0.123478              0.079344
# AverageForecast                 0.070902      0.149711              0.116053
# Error                          -0.001057     -0.166390             -0.199141
# AbsError                        0.030148      0.012406             -0.056072
# PercentError                    0.118907     -0.284819             -0.296413
# AbsPE                           0.074924     -0.247267             -0.290541
# UnemploymentRate_ForecastYear  -0.038831      0.159560              0.252636
# UnemploymentRate_YearProduced   0.296260      0.297625              0.305899
# UnemploymentRate_OpeningYear   -0.080655      0.212528              0.282842
# Diff_Year                       0.221174     -0.453070             -0.751871
# UnifiedImprovementType          0.160816     -0.469007             -0.477654
# Forecast_Method                 0.502525      0.181944              0.378636
# Area_Type                       1.000000     -0.317800             -0.255587
# ForecastYear                   -0.317800      1.000000              0.898511
# YearForecastProduced           -0.255587      0.898511              1.000000
# Year_ofObservation             -0.256659      0.902198              0.894531
# ImprovementType                -0.095023     -0.210716             -0.337287
# Agency                         -0.079319      0.386446              0.430289
# FunctionalClass                 0.408581     -0.422183             -0.476163
#
#                                Year_ofObservation  ImprovementType    Agency  \
# HashProjectID                           -0.283651         0.014163 -0.404996
# AverageCount                             0.129281         0.017443  0.049027
# AverageForecast                          0.160065         0.004083  0.066050
# Error                                   -0.189619         0.055775 -0.096758
# AbsError                                 0.037824         0.067371 -0.028999
# PercentError                            -0.251330         0.052886 -0.147591
# AbsPE                                   -0.184862         0.121001 -0.187950
# UnemploymentRate_ForecastYear            0.105990        -0.299233  0.471783
# UnemploymentRate_YearProduced            0.226051        -0.134245  0.089336
# UnemploymentRate_OpeningYear             0.130307        -0.268347  0.497271
# Diff_Year                               -0.490977         0.348666 -0.425811
# UnifiedImprovementType                  -0.386851         0.877482 -0.690365
# Forecast_Method                          0.227446        -0.486378  0.514207
# Area_Type                               -0.256659        -0.095023 -0.079319
# ForecastYear                             0.902198        -0.210716  0.386446
# YearForecastProduced                     0.894531        -0.337287  0.430289
# Year_ofObservation                       1.000000        -0.242655  0.246853
# ImprovementType                         -0.242655         1.000000 -0.539328
# Agency                                   0.246853        -0.539328  1.000000
# FunctionalClass                         -0.280274         0.252853 -0.741832
#
#                                FunctionalClass
# HashProjectID                         0.643019
# AverageCount                         -0.197636
# AverageForecast                      -0.222904
# Error                                 0.188645
# AbsError                             -0.067347
# PercentError                          0.171529
# AbsPE                                 0.225149
# UnemploymentRate_ForecastYear        -0.434333
# UnemploymentRate_YearProduced         0.045099
# UnemploymentRate_OpeningYear         -0.465833
# Diff_Year                             0.484444
# UnifiedImprovementType                0.452535
# Forecast_Method                      -0.218833
# Area_Type                             0.408581
# ForecastYear                         -0.422183
# YearForecastProduced                 -0.476163
# Year_ofObservation                   -0.280274
# ImprovementType                       0.252853
# Agency                               -0.741832
# FunctionalClass                       1.000000

# %%
x = ['AverageCount','AverageForecast','Error','AbsError','UnemploymentRate_OpeningYear', 'Diff_Year','ForecastYear', 'YearForecastProduced', 'Year_ofObservation']
y = ['PercentError']

sns.pairplot(df,x_vars = x, y_vars = y, kind='reg')

# %%
sns.pairplot(df, x_vars = x, y_vars = 'AbsPE', kind = 'reg')
